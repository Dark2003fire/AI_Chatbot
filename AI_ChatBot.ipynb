# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = []
classes = []
documents = []
ignore_letters = ['?', '!',',','.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list,intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
output_empty = [0] * len(classes)

for document in documents:
    bag =[]
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbotmodel.h5', hist)

print('Done')
# Out:
# Epoch 1/200
# C:\Users\hjha0\AppData\Local\Temp\ipykernel_12388\3465315219.py:56: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# C:\Users\hjha0\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 12/12 [==============================] - 1s 2ms/step - loss: 2.9318 - accuracy: 0.0517
# Epoch 2/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8635 - accuracy: 0.0690
# Epoch 3/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8401 - accuracy: 0.1207
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6443 - accuracy: 0.2414
# Epoch 5/200
# 12/12 [==============================] - 0s 1ms/step - loss: 2.6524 - accuracy: 0.1552
# Epoch 6/200
# 12/12 [==============================] - 0s 1ms/step - loss: 2.5295 - accuracy: 0.2241
# Epoch 7/200
# 12/12 [==============================] - 0s 1ms/step - loss: 2.4117 - accuracy: 0.3103
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2776 - accuracy: 0.3276
# Epoch 9/200
# 12/12 [==============================] - 0s 1ms/step - loss: 2.2683 - accuracy: 0.3103
# Epoch 10/200
# 12/12 [==============================] - 0s 1ms/step - loss: 2.1669 - accuracy: 0.3276
# Epoch 11/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1519 - accuracy: 0.3966
# Epoch 12/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8849 - accuracy: 0.4138
# Epoch 13/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7720 - accuracy: 0.4655
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8152 - accuracy: 0.4483
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6842 - accuracy: 0.4828
# Epoch 16/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5358 - accuracy: 0.5345
# Epoch 17/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.6660 - accuracy: 0.4655
# Epoch 18/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4019 - accuracy: 0.5690
# Epoch 19/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.3179 - accuracy: 0.6207
# Epoch 20/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.2050 - accuracy: 0.5690
# Epoch 21/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0550 - accuracy: 0.6724
# Epoch 22/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0031 - accuracy: 0.7069
# Epoch 23/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8436 - accuracy: 0.7759
# Epoch 24/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0570 - accuracy: 0.6724
# Epoch 25/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1199 - accuracy: 0.6724
# Epoch 26/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9544 - accuracy: 0.7241
# Epoch 27/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8036 - accuracy: 0.8103
# Epoch 28/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9938 - accuracy: 0.6897
# Epoch 29/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7994 - accuracy: 0.7759
# Epoch 30/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7134 - accuracy: 0.7931
# Epoch 31/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6313 - accuracy: 0.7759
# Epoch 32/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7626 - accuracy: 0.7586
# Epoch 33/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7471 - accuracy: 0.7759
# Epoch 34/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.8103
# Epoch 35/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6396 - accuracy: 0.7241
# Epoch 36/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6905 - accuracy: 0.7414
# Epoch 37/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5790 - accuracy: 0.7759
# Epoch 38/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6224 - accuracy: 0.8103
# Epoch 39/200
# 12/12 [==============================] - 0s 1000us/step - loss: 0.5768 - accuracy: 0.8621
# Epoch 40/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5004 - accuracy: 0.8448
# Epoch 41/200
# 12/12 [==============================] - 0s 1000us/step - loss: 0.4888 - accuracy: 0.8966
# Epoch 42/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4503 - accuracy: 0.8621
# Epoch 43/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3776 - accuracy: 0.8448
# Epoch 44/200
# 12/12 [==============================] - 0s 1000us/step - loss: 0.4020 - accuracy: 0.8621
# Epoch 45/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5666 - accuracy: 0.7931
# Epoch 46/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3775 - accuracy: 0.8793
# Epoch 47/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4087 - accuracy: 0.8793
# Epoch 48/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.8793
# Epoch 49/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3465 - accuracy: 0.8966
# Epoch 50/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5886 - accuracy: 0.7759
# Epoch 51/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3205 - accuracy: 0.9310
# Epoch 52/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5375 - accuracy: 0.7931
# Epoch 53/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3697 - accuracy: 0.8621
# Epoch 54/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3947 - accuracy: 0.8276
# Epoch 55/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3531 - accuracy: 0.9138
# Epoch 56/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2269 - accuracy: 0.8966
# Epoch 57/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3596 - accuracy: 0.8621
# Epoch 58/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8276
# Epoch 59/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2983 - accuracy: 0.8793
# Epoch 60/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3712 - accuracy: 0.8966
# Epoch 61/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3645 - accuracy: 0.8793
# Epoch 62/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3611 - accuracy: 0.8793
# Epoch 63/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4779 - accuracy: 0.8621
# Epoch 64/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2833 - accuracy: 0.9310
# Epoch 65/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3600 - accuracy: 0.9138
# Epoch 66/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.9310
# Epoch 67/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3141 - accuracy: 0.8966
# Epoch 68/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2481 - accuracy: 0.9483
# Epoch 69/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.8448
# Epoch 70/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3942 - accuracy: 0.8793
# Epoch 71/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4066 - accuracy: 0.8621
# Epoch 72/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3182 - accuracy: 0.8966
# Epoch 73/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2622 - accuracy: 0.9138
# Epoch 74/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2217 - accuracy: 0.9483
# Epoch 75/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3931 - accuracy: 0.8793
# Epoch 76/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1842 - accuracy: 0.9655
# Epoch 77/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1754 - accuracy: 0.9483
# Epoch 78/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2875 - accuracy: 0.8966
# Epoch 79/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2867 - accuracy: 0.9138
# Epoch 80/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1658 - accuracy: 0.9655
# Epoch 81/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1880 - accuracy: 0.9483
# Epoch 82/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2317 - accuracy: 0.9310
# Epoch 83/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3461 - accuracy: 0.8448
# Epoch 84/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2109 - accuracy: 0.9655
# Epoch 85/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2399 - accuracy: 0.9310
# Epoch 86/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2587 - accuracy: 0.8793
# Epoch 87/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1760 - accuracy: 0.9483
# Epoch 88/200
# 12/12 [==============================] - 0s 1000us/step - loss: 0.3266 - accuracy: 0.8621
# Epoch 89/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2177 - accuracy: 0.9310
# Epoch 90/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2012 - accuracy: 0.9310
# Epoch 91/200
# 12/12 [==============================] - 0s 909us/step - loss: 0.1635 - accuracy: 0.9655
# Epoch 92/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2796 - accuracy: 0.9310
# Epoch 93/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2696 - accuracy: 0.9138
# Epoch 94/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2173 - accuracy: 0.9310
# Epoch 95/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9655
# Epoch 96/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.9138
# Epoch 97/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3116 - accuracy: 0.8793
# Epoch 98/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.9138
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1925 - accuracy: 0.9483
# Epoch 100/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3148 - accuracy: 0.8621
# Epoch 101/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2020 - accuracy: 0.9655
# Epoch 102/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1916 - accuracy: 0.9655
# Epoch 103/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.9138
# Epoch 104/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.9483
# Epoch 105/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.9138
# Epoch 106/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2968 - accuracy: 0.8793
# Epoch 107/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1684 - accuracy: 0.9483
# Epoch 108/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2585 - accuracy: 0.8621
# Epoch 109/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2144 - accuracy: 0.9138
# Epoch 110/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 0.9483
# Epoch 111/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2473 - accuracy: 0.9138
# Epoch 112/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9483
# Epoch 113/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1283 - accuracy: 0.9655
# Epoch 114/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1571 - accuracy: 0.9310
# Epoch 115/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1886 - accuracy: 0.9483
# Epoch 116/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2356 - accuracy: 0.9310
# Epoch 117/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1751 - accuracy: 0.9655
# Epoch 118/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1901 - accuracy: 0.9483
# Epoch 119/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2321 - accuracy: 0.9483
# Epoch 120/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1577 - accuracy: 0.9483
# Epoch 121/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2210 - accuracy: 0.9310
# Epoch 122/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2394 - accuracy: 0.8793
# Epoch 123/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 0.9310
# Epoch 124/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 1.0000
# Epoch 125/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2281 - accuracy: 0.8966
# Epoch 126/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1167 - accuracy: 0.9655
# Epoch 127/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2753 - accuracy: 0.8966
# Epoch 128/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1277 - accuracy: 0.9483
# Epoch 129/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9483
# Epoch 130/200
# 12/12 [==============================] - 0s 1000us/step - loss: 0.2115 - accuracy: 0.9138
# Epoch 131/200
# 12/12 [==============================] - 0s 455us/step - loss: 0.2192 - accuracy: 0.9138
# Epoch 132/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1415 - accuracy: 0.9310
# Epoch 133/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2562 - accuracy: 0.8966
# Epoch 134/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1807 - accuracy: 0.9310
# Epoch 135/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9828
# Epoch 136/200
# 12/12 [==============================] - 0s 909us/step - loss: 0.1458 - accuracy: 0.9655
# Epoch 137/200
# 12/12 [==============================] - 0s 460us/step - loss: 0.3424 - accuracy: 0.8966
# Epoch 138/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1411 - accuracy: 0.9310
# Epoch 139/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1791 - accuracy: 0.9310
# Epoch 140/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.8966
# Epoch 141/200
# 12/12 [==============================] - 0s 0s/step - loss: 0.1612 - accuracy: 0.9483
# Epoch 142/200
# 12/12 [==============================] - 0s 0s/step - loss: 0.1178 - accuracy: 0.9655
# Epoch 143/200
# 12/12 [==============================] - 0s 0s/step - loss: 0.1098 - accuracy: 0.9655
# Epoch 144/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1710 - accuracy: 0.9138
# Epoch 145/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1485 - accuracy: 0.9655
# Epoch 146/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.9828
# Epoch 147/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1542 - accuracy: 0.9483
# Epoch 148/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1516 - accuracy: 0.9310
# Epoch 149/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1713 - accuracy: 0.9483
# Epoch 150/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1492 - accuracy: 0.9483
# Epoch 151/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1308 - accuracy: 0.9655
# Epoch 152/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1947 - accuracy: 0.9138
# Epoch 153/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1486 - accuracy: 0.9483
# Epoch 154/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2064 - accuracy: 0.8966
# Epoch 155/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9483
# Epoch 156/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.8793
# Epoch 157/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1490 - accuracy: 0.9310
# Epoch 158/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1277 - accuracy: 0.9483
# Epoch 159/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9655
# Epoch 160/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1380 - accuracy: 0.9483
# Epoch 161/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2012 - accuracy: 0.9483
# Epoch 162/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1705 - accuracy: 0.9310
# Epoch 163/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1919 - accuracy: 0.9310
# Epoch 164/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.9310
# Epoch 165/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1282 - accuracy: 0.9483
# Epoch 166/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1406 - accuracy: 0.9483
# Epoch 167/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1147 - accuracy: 0.9483
# Epoch 168/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1539 - accuracy: 0.9138
# Epoch 169/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1250 - accuracy: 0.9310
# Epoch 170/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.9138
# Epoch 171/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1306 - accuracy: 0.9483
# Epoch 172/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1593 - accuracy: 0.9310
# Epoch 173/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9483
# Epoch 174/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1081 - accuracy: 0.9655
# Epoch 175/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1499 - accuracy: 0.9655
# Epoch 176/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2498 - accuracy: 0.8966
# Epoch 177/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1372 - accuracy: 0.9655
# Epoch 178/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.9310
# Epoch 179/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1133 - accuracy: 0.9483
# Epoch 180/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2215 - accuracy: 0.9310
# Epoch 181/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2052 - accuracy: 0.9310
# Epoch 182/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1725 - accuracy: 0.9138
# Epoch 183/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1129 - accuracy: 0.9655
# Epoch 184/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1900 - accuracy: 0.9310
# Epoch 185/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1249 - accuracy: 0.9483
# Epoch 186/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0773 - accuracy: 1.0000
# Epoch 187/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1200 - accuracy: 0.9483
# Epoch 188/200
# 12/12 [==============================] - 0s 1000us/step - loss: 0.1864 - accuracy: 0.8966
# Epoch 189/200
# 12/12 [==============================] - 0s 209us/step - loss: 0.1722 - accuracy: 0.9483
# Epoch 190/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1590 - accuracy: 0.9138
# Epoch 191/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1370 - accuracy: 0.9483
# Epoch 192/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1888 - accuracy: 0.9138
# Epoch 193/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1353 - accuracy: 0.9483
# Epoch 194/200
# 12/12 [==============================] - 0s 1000us/step - loss: 0.1187 - accuracy: 0.9655
# Epoch 195/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1288 - accuracy: 0.9483
# Epoch 196/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1609 - accuracy: 0.9310
# Epoch 197/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1777 - accuracy: 0.9138
# Epoch 198/200
# 12/12 [==============================] - 0s 0s/step - loss: 0.1428 - accuracy: 0.9310
# Epoch 199/200
# 12/12 [==============================] - 0s 0s/step - loss: 0.0762 - accuracy: 0.9828
# Epoch 200/200
# 12/12 [==============================] - 0s 0s/step - loss: 0.2323 - accuracy: 0.9138
# Done

# %%
### Author: Riya Nakarmi ###
### College Project ###

import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model


lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbotmodel.h5')

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word)  for word in sentence_words]
    return sentence_words

def bag_of_words(sentence):
    sentence_words= clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1

    return np.array(bag)

def predict_class(sentence):
    bow = bag_of_words(sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda  x:x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
    return return_list


def get_response(intents_list,intents_json):
    tag= intents_list[0]['intent']
    list_of_intents =intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

print("|============= Welcome to College Equiry Chatbot System! =============|")
print("|============================== Feel Free ============================|")
print("|================================== To ===============================|")
print("|=============== Ask your any query about our college ================|")
while True:
    message = input("| You: ")
    if message == "bye" or message == "Goodbye":
        ints = predict_class(message)
        res = get_response(ints, intents)
        print("| Bot:", res)
        print("|===================== The Program End here! =====================|")
        exit()

    else:
        ints = predict_class(message)
        res = get_response(ints, intents)
        print("| Bot:", res)
